# %%
import pandas as pd
import geopandas as geopandas
import hkvsobekpy
from pathlib import Path

# %%
# %load_ext autoreload
# %autoreload 2

# %%
dir_model = "..\\..\\WRIJ_RR_Unpaved_methode_02_input\\rr_input_area_scenario\\gebied_1\\scenario_test\\rr_model\\rr\\"
unpaved_rr_file = "upflowdt.his"

# %%
rr_his = hkvsobekpy.read_his.ReadMetadata(Path(dir_model, unpaved_rr_file))

# %%
rr_his.DataFrame().head().columns.levels[0]
# Out:
# Index(['Actual Evap. [m3/s] ', 'Capill.Rise  [m3/s] ', 'Evap. surface[m3/s] ',
#        'GW>Threshold [hour] ', 'GWLevel-Surface[m]  ', 'Groundw.Level   [m] ',
#        'Groundw.Volume [m3] ', 'Groundw.outfl.[m3/s]', 'Infiltration [m3/s] ',
#        'Inundation perc.[%] ', 'Irrigat.GWdem[m3/s] ', 'IrrigationSup[m3/s] ',
#        'Net Seepage  [m3/s] ', 'Percolation  [m3/s] ', 'Pot. Evapor. [m3/s] ',
#        'Rainfall     [m3/s] ', 'Storage Land   [m3] ', 'Storage Land   [mm] ',
#        'Storage coefficient ', 'Surf. Runoff  [m3/s]', 'Unsat.Zone    [mm]  ',
#        'Vol.Unsat.Zone[m3]  '],
#       dtype='object')

# %%
rr_his.DataFrame()['Link flow [m3/s]    '].sum(axis=1).plot()
# Out:
# <Axes: >
